# %%
from ultralytics import YOLO

# Load the trained model from the best weights
model = YOLO("runs/ball-yolov83/weights/best.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
#results = model("datasets/dataset/images/train/ball_1.jpg")
#results = model("raw/sample3.jpg")
results = model("raw/sample.jpg", conf=0.7)  # Only keep boxes with 70%+
# Out:
# image 1/1 /app/project_13/raw/sample.jpg: 192x640 10 balls, 81.4ms
# Speed: 1.0ms preprocess, 81.4ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)

# %%
import matplotlib.pyplot as plt

img_with_boxes = results[0].plot()  # Draw boxes on image
plt.imshow(img_with_boxes)
plt.axis('off')
plt.title("Prediction")
plt.show()

# %%
#model.val(data="data.yaml", imgsz=640)

# %%
import cv2

cap = cv2.VideoCapture(0)  # 0 = default webcam

if not cap.isOpened():
    print("❌ Cannot open webcam")
else:
    print("✅ Webcam opened successfully")

cap.release()
# Out:
# ❌ Cannot open webcam
# [ WARN:0@13.144] global cap_v4l.cpp:913 open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# [ERROR:0@13.144] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range

# %%
import cv2
from ultralytics import YOLO

model = YOLO("runs/ball-yolov8/weights/best.pt")  # Your trained model

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        print("❌ Failed to grab frame")
        break

    results = model(frame, conf=0.5)
    annotated = results[0].plot()

    cv2.imshow("YOLOv8 Detection", annotated)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
results_old = YOLO("runs/old_model/weights/best.pt")(img)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 results_old = YOLO("runs/old_model/weights/best.pt")(img)
#
# File /usr/local/lib/python3.10/site-packages/ultralytics/models/yolo/model.py:23, in YOLO.__init__(self, model, task, verbose)
#      20     self.__dict__ = new_instance.__dict__
#      21 else:
#      22     # Continue with default YOLO initialization
# ---> 23     super().__init__(model=model, task=task, verbose=verbose)
#
# File /usr/local/lib/python3.10/site-packages/ultralytics/engine/model.py:148, in Model.__init__(self, model, task, verbose)
#     146     self._new(model, task=task, verbose=verbose)
#     147 else:
# --> 148     self._load(model, task=task)
#     150 # Delete super().training for accessing self.model.training
#     151 del self.training
#
# ...

# %%
results_old = YOLO("runs/old_model/weights/best.pt")(img)
