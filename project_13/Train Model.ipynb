# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")

# %%
import os
print("Current working directory:", os.getcwd())
print("Data.yaml exists:", os.path.exists("data.yaml"))
# Out:
# Current working directory: /app/project_13
# Data.yaml exists: True

# %%
import os

print(os.path.exists("dataset/images/train"))  # True
print(os.path.exists("dataset/images/val"))    # True
print(os.path.exists("data.yaml"))
# Out:
# False
# False
# True

# %%
from pathlib import Path

# This will delete Ultralytics' saved settings
settings_path = Path("/root/.config/Ultralytics/settings.yaml")

if settings_path.exists():
    settings_path.unlink()
    print("✅ Ultralytics settings cache deleted.")
else:
    print("⚠️ No settings cache found — that's okay.")
# Out:
# ⚠️ No settings cache found — that's okay.

# %%
model = YOLO("yolov8s.pt")
model.train(
    data="data.yaml",
    epochs=50,
    imgsz=640,
    batch=8,
    project="runs",
    name="ball-yolov8"
)
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 208MB/s]
# Ultralytics 8.3.96 🚀 Python-3.10.16 torch-2.6.0+cu124 CPU (Intel Core(TM) i5-9500 3.00GHz)
# ...

# %%
import matplotlib.pyplot as plt
from ultralytics import YOLO

# Load trained model
model = YOLO("runs/ball-yolov8/weights/best.pt")

# Inference on an image
results = model("datasets/dataset/images/val/ball_1.jpg")

# Plot result in Jupyter
img_with_boxes = results[0].plot()
plt.imshow(img_with_boxes)
plt.axis('off')
plt.title("YOLOv8 Detection Result")
plt.show()
# Out:
# image 1/1 /app/project_13/datasets/dataset/images/val/ball_1.jpg: 640x544 (no detections), 117.5ms
# Speed: 2.6ms preprocess, 117.5ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 544)
