# %%
name = "qayyum"
age  = 34
height = 164.0

print(name)
print(age)
print(height)
# Out:
# qayyum
# 34
# 164.0

# %%
def greeting(name):
    return f"hello,{name}"

greeting(name)
# Out:
# 'hello,qayyum'

# %%
for i in range(1,6):
    print(name)
# Out:
# qayyum
# qayyum
# qayyum
# qayyum
# qayyum

# %%
fruits = ["apple","grape","banana"]
for i in fruits:
    print("buah:",i)
# Out:
# buah: apple
# buah: grape
# buah: banana

# %%
if age > 18:
    print(f"your are mature");
else:
    print(f"still children")
# Out:
# your are mature

# %%
count_bee = 120

if count_bee < 30:
    print("need to check the hive")
elif count_bee < 100:
    print("in good condition")
else:
    print("split the hive!")
# Out:
# split the hive!
