# %%
try:
    x = 1/0
except ZeroDivisionError:
    print("cannnot devide by zero")
# Out:
# cannnot devide by zero

# %%
try:
    val = int('abc')
except Exception as e:
    print(e)
# Out:
# invalid literal for int() with base 10: 'abc'

# %%
#own exception
age = -5
if age <= 0:
    raise ValueError("value cannot less then 0")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 4
#       2 age = -5
#       3 if age <= 0:
# ----> 4     raise ValueError("value cannot less then 0")
#
# ValueError: value cannot less then 0
