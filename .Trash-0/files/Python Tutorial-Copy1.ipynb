# %%
#print message
print("hello world!")
# Out:
# hello world!

# %%
#check version
import sys
print(sys.version)
# Out:
# 3.10.16 (main, Feb  5 2025, 12:53:27) [GCC 12.2.0]

# %%
if 5 == 5:
    print(True)
# Out:
# True

# %%
if True:
        print(True)
# Out:
# True

# %%
#variable
x = 5
y = "hello world"

# %%
#This is a comment.

# %%
"""
This is a comment
written in
more than just one line
"""
print("Hello, World!")
# Out:
# Hello, World!

# %%
#variable
x=5
y="john"
print(x)
print(y)
# Out:
# 5
# john

# %%
#casting
x=str(3)
y=float(3)
z=int(3)
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'int'>

# %%
#case sensitive
a = 4
A = "Sally"
#A will not overwrite a

# %%
#Assign Multiple Values
x,y,z = "Orange","Apple","Banana"
print(x)
print(y)
print(z)
# Out:
# Orange
# Apple
# Banana

# %%
#One Value to Multiple Variables
x = y = z = "Orange"
print(x)
# Out:
# Orange

# %%
#Unpack a Collection (unpack from collection/list/taple/etc to variables
fruits = ["A","B","C"]
x,y,z = fruits
print(x)
print(y)
print(z)
# Out:
# A
# B
# C

# %%
x = "python awesome"
y = ".Yeah"
z = "!!"
print(x)
print(x,y,z)
print(x+y+z)

x=5
y=5
print(x+y)
print(x,y,z)
# Out:
# python awesome
# python awesome .Yeah !!
# python awesome.Yeah!!
# 10
# 5 5 !!

# %%
#global variables

x = "hello world"

def myFunction():
    print("--->",x)

myFunction()
# Out:
# ---> hello world

# %%
#global variables

x = "hello world"

def myFunction():
    x="override"
    print("--->",x)

myFunction()
# Out:
# ---> override

# %%
#assign global variable inside the function
def myFunction():
    global x
    x = "hello world"

myFunction()
print("hai,",x)
# Out:
# hai, hello world

# %%
#Random Number Library
import random as r
print(r.randrange(1,10))
# Out:
# 2

# %%
#Strings
print("hello world")
print('hello world')
# Out:
# hello world
# hello world

# %%
print("It's Alright!")
print('Hello" World')
# Out:
# It's Alright!
# Hello" World

# %%
a = "values"
print(a)
# Out:
# values

# %%
a = """
        Hello Son!
    """
print(a)
# Out:
#         Hello Son!

# %%
a = '''
        Hello Son!
    '''
print(a)
# Out:
#         Hello Son!

# %%
#Strings are Arrays

a = "Hello World"
print(a[0])
# Out:
# H

# %%
#loop each string value array
for x in "Hello world":
    print(x)
# Out:
# H
# e
# l
# l
# o
#
# w
# o
# r
# l
# d

# %%
#String length
print(len(a))
print(a)
# Out:
# 11
# Hello World

# %%
#Check if word 'the' in variable x
x="Hello World,I'am the order"
if "the" in x:
    print(True)
# Out:
# True

# %%
x="Hello World,I'am the order"
print('khoi' not in x)
# Out:
# True

# %%
if 'expensive' not in 'hello world,exception':
    print(True)
# Out:
# True

# %%
#Slicing
#Get the characters from position 2 to position 5 (not included):
b = "Hello, World!"
print(b[2:5])
# Out:
# llo

# %%
#Get the characters from the start to position 5 (not included):
b = "Hello, World!"
print(b[:5])
# Out:
# Hello

# %%
#Get the characters from position 2, and all the way to the end:
print(b[2:])
# Out:
# llo, World!

# %%
b = "Hello, World!"
print(b[-5:-2])
# Out:
# orl

# %%
#upper case
print("hello world".upper())
# Out:
# HELLO WORLD

# %%
#lower case
print("PRINT".lower())
# Out:
# print

# %%
#remove whitespace
print(" hello,world! ".strip())
# Out:
# hello,world!

# %%
#replace word
print("hello".replace('h','y'))
# Out:
# yello

# %%
#split string by ','
print("hello,world".split(','))
# Out:
# ['hello', 'world']

# %%
#Concatenation
a = "hello"
b = "world"

print(a+b)
# Out:
# helloworld

# %%
print(a+" "+b)
# Out:
# hello world

# %%
age = 34;
name = "qayyum"
print(f"my name is {name},Iam {age} year's old")
# Out:
# my name is qayyum,Iam 34 year's old

# %%
#add decimal point
price =59;
print(f"the price is {price:.2f} dollars")
# Out:
# the price is 59.00 dollars

# %%
print(f"{1+2}")
# Out:
# 3

# %%
#Escape Characters
print("those are \"viking\"")
# Out:
# those are "viking"

# %%
print(True)
print(1<0)

if True:
    print(True)
else:
    print(False)
# Out:
# True
# False
# True

# %%
print(bool(15))
print(bool("ayam"))
print(bool(""))
print(bool(0))
print(bool(["apple","Grape"]))
# Out:
# True
# True
# False
# False
# True

# %%
bool(False)
bool(None)
bool(0)
bool("")
bool(())
bool([])
bool({})
# Out:
# False

# %%
x=200
print(isinstance(x,int))
# Out:
# True

# %%
x=200
print(isinstance(x,bool))
# Out:
# False

# %%
print(True not True)
# Out:
#   Cell In[2], line 1
#     print(True not True)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
