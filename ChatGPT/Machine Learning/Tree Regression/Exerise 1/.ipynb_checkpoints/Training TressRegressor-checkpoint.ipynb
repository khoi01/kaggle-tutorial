# %%
# Re-import necessary libraries after execution state reset
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.preprocessing import LabelEncoder

import pandas as pd

#import data from .csv file
data=pd.read_csv('camera_rental_data.csv')



#Features (X) , Target (Y)
X = data['Camera_Model']
y = data['Days_Rented']


# from sklearn.preprocessing import LabelEncoder

# le = LabelEncoder()
data['Camera_Model'] = le.fit_transform(data['Camera_Model'])
#Train TreeRegressor Model
# tree_reg = DecisionTreeRegressor(max_depth=3, random_state=42)
# tree_reg.fit(X, y)
# print(data['Camera_Model'])
# Out:
# 0    3
# 1    0
# 2    1
# 3    3
# 4    2
# 5    0
# 6    1
# 7    3
# 8    2
# 9    0
# Name: Camera_Model, dtype: int64

# %%
print(data)
# Out:
#   Customer_Name  Camera_Model  Days_Rented
# 0          John             3            5
# 1         Sarah             0            3
# 2           Ali             1            7
# 3         Emily             3            4
# 4          Mike             2            6
# 5         David             0            2
# 6          Anna             1           10
# 7         James             3            3
# 8        Sophia             2            8
# 9        Daniel             0            5

# %%
print(data["Customer_Name"])
# Out:
# 0      John
# 1     Sarah
# 2       Ali
# 3     Emily
# 4      Mike
# 5     David
# 6      Anna
# 7     James
# 8    Sophia
# 9    Daniel
# Name: Customer_Name, dtype: object
